# %%
from dotenv import load_dotenv
load_dotenv()
import rich

# %%
from langfuse import Langfuse
langfuse = Langfuse()

# %%
test = langfuse.get_trace(
    # id="ab53a060-a4df-4a78-80f2-b34cffc3300e"
    id="69bc41fe-218d-421d-81c6-1a01ac5cd472"
    )
rich.print(test.dict())
# Out:
# {
#     'id': '69bc41fe-218d-421d-81c6-1a01ac5cd472',
#     'timestamp': datetime.datetime(2025, 3, 7, 8, 36, 23, 830000, tzinfo=datetime.timezone.utc),
#     'name': 'LangGraph',
#     'input': {
#         'messages': [
#             {
#                 'content': 'What is Langfuse?',
#                 'additional_kwargs': {},
#                 'response_metadata': {},
#                 'type': 'human',
#                 'name': None,
#                 'id': '1855885b-51ea-47d5-9de0-7d992216fe24',
#                 'example': False
#             }
#         ]
#     },
#     'output': {
#         'messages': [
#             {
#                 'content': 'What is Langfuse?',
#                 'additional_kwargs': {},
#                 'response_metadata': {},
#                 'type': 'human',
#                 'name': None,
#                 'id': '1855885b-51ea-47d5-9de0-7d992216fe24',
#                 'example': False
#             },
#             {
# ...

# %%
def find_latency_pairs(d):
    results = []

    if isinstance(d, dict):
        for key, value in d.items():
            if key == "latency":
                results.append(value)
            if isinstance(value, (dict, list)):
                find_latency_pairs(value, results)
    
    elif isinstance(d, list):
        for item in d:
            if isinstance(item, (dict, list)):
                find_latency_pairs(item, results)

    return results

# %%
res = find_latency_pairs(test.dict())

# %%
res
# Out:
# [7.384, 7376.0, 7384.0, 7378.0, 0.0, 0.0, 0.0, 0.0]
